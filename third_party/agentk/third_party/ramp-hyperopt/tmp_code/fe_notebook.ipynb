# %%
import os 
import rampwf as rw
import ramphy as rh
from pathlib import Path
import shutil

challenge = "kaggle_synthanic_v1_1_nX"
# source_path = Path("/home/gpaolo/nas/ramp-kits")
source_path = Path("/home/gpaolo/ramp-kits")
# Out:
# /home/gpaolo/miniforge3/envs/pangu/lib/python3.10/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.19) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# ...

# %%
best_submissions = []

# %%
result = rh.actions.select_top_hyperopt(ramp_kit_dir=str(source_path/challenge), submission='lgbm', top_n=1, fold_idxs=range(900, 931))
print(result)
best_submissions.append(result["selected_submissions"][0])
# Out:
# Loading existing hyperopt submissions...
# Selected 1 submissions
# score_cutoff = 0.7779838709677419
# {'selected_submissions': ['lgbm_hyperopt_faf11a96b9'], 'score_cutoff': 0.7779838709677419}

# %%
result = rh.actions.select_top_hyperopt(ramp_kit_dir=str(source_path/challenge), submission='catboost', fold_idxs=range(900, 931), top_n=1)
print(result)
best_submissions.append(result["selected_submissions"][0])
# Out:
# Loading existing hyperopt submissions...
# Selected 1 submissions
# score_cutoff = 0.7752677419354839
# {'selected_submissions': ['catboost_hyperopt_3c8f92cea0'], 'score_cutoff': 0.7752677419354839}

# %%
result = rh.actions.select_top_hyperopt(ramp_kit_dir=str(source_path/challenge), submission='xgboost', fold_idxs=range(900, 931), top_n=1)
print(result)
best_submissions.append(result["selected_submissions"][0])
# Out:
# Loading existing hyperopt submissions...
# Selected 1 submissions
# score_cutoff = 0.7781225806451613
# {'selected_submissions': ['xgboost_hyperopt_c84cad608f'], 'score_cutoff': 0.7781225806451613}

# %%
# for submission in best_submissions:
#     dst_dir = destination_path / challenge / 'submissions' / submission
#     src_dir = source_path / challenge / 'submissions' / submission
#     new_name = submission.split("_")[:-1]
#     new_name.append("best")
#     new_name = "_".join(new_name)
#     print(f"Moving \n - {src_dir} \n - {dst_dir}")
#     shutil.copytree(src_dir, dst_dir, dirs_exist_ok=True)
#     print(f"Renaming it to {new_name}")
#     os.rename(dst_dir, destination_path/challenge/"submissions"/new_name)
#     print("Done")
# Out:
# Moving
#  - /home/gpaolo/nas/ramp-kits/kaggle_synthanic_v1_1_n1/submissions/lgbm_hyperopt_548fff4dd9
#  - /home/gpaolo/ramp-kits/kaggle_synthanic_v1_1_n1/submissions/lgbm_hyperopt_548fff4dd9
#  Renaming it to lgbm_hyperopt_best
# Moving
#  - /home/gpaolo/nas/ramp-kits/kaggle_synthanic_v1_1_n1/submissions/catboost_hyperopt_ae9761184b
#  - /home/gpaolo/ramp-kits/kaggle_synthanic_v1_1_n1/submissions/catboost_hyperopt_ae9761184b
#  Renaming it to catboost_hyperopt_best
# Moving
#  - /home/gpaolo/nas/ramp-kits/kaggle_synthanic_v1_1_n1/submissions/xgboost_hyperopt_3aafe3160a
#  - /home/gpaolo/ramp-kits/kaggle_synthanic_v1_1_n1/submissions/xgboost_hyperopt_3aafe3160a
#  Renaming it to xgboost_hyperopt_best
